# %% [markdown]
# # Класс Account

# %%
from decimal import Decimal
from Account import Account

# %%
account2 = Account("Nil", Decimal('50.00'))

# %%
account2.name
# Out:
# 'Nil'

# %% [markdown]
# ##  Управление доступом к атрибутам

# %%
account2.balance = Decimal('-1000')

# %%
account2.balance
# Out:
# Decimal('-1000')

# %% [markdown]
# #  Использование свойств для доступа к данным

# %%
from timewithproperties import Time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-7c09a6199620> in <module>
# ----> 1 from timewithproperties import Time
#
# ModuleNotFoundError: No module named 'timewithproperties'

# %%
time1 = Time(hour=10,minute=59,sec=59)

# %%
time1.hour = 20

# %%
time1.set_time(0,1,2)

# %%
time1.hour

# %%
wake_up = Time(hour=6,minute=28)

# %%
wake_up

# %%
print(wake_up)

# %% [markdown]
# ## Практический пример: моделирование тасования и сдачи карт

# %%
from deck import DeckOfCards
one = DeckOfCards()

one.shuffle()
one.deal_card()
# Out:
# Card(face='6', suit='hearts')

# %%
from pathlib import Path
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
path = Path('.').joinpath('card_images')
figure,axes_list = plt.subplots(nrows = 4, ncols = 13)
for axes in axes_list.ravel():
    axes.get_xaxis().set_visible(False)
    axes.get_yaxis().set_visible(False)
    image_name = one.deal_card().image_name
    img = mpimg.imread(str(path.joinpath(image_name).resolve()))
    axes.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-6fa82778d317> in <module>
#       7     axes.get_xaxis().set_visible(False)
#       8     axes.get_yaxis().set_visible(False)
# ----> 9     image_name = one.deal_card().image_name
#      10     img = mpimg.imread(str(path.joinpath(image_name).resolve()))
#      11     axes.imshow(img)
#
# AttributeError: 'NoneType' object has no attribute 'image_name'

# %%
from CommissionEmployee import CommissionEmployee
from decimal import Decimal
from salariedcommissionemployee import SalariedCommissionEmployee
s = CommissionEmployee('Rav',"Vas",'133-33-3333',Decimal(10000.00), Decimal(0.06))
c = SalariedCommissionEmployee('Ravil',"Vasilev",'333-33-3333',Decimal(10000.00), Decimal(0.06),Decimal(32000.00))

# %%
c
# Out:
# SalariedCommissionEmployee:  Ravil Vasilev
# номер соц страхования: 333-33-3333
# обьем продаж: 10000.00
# комиссионная ставка: 0.06
# base salary: 32000.00

# %%
s
# Out:
# CommissionEmployee:  Rav Vas
# номер соц страхования: 133-33-3333
# обьем продаж: 10000.00
# комиссионная ставка: 0.06

# %%
c.commision_rate = Decimal(0.6)
c.gross_sales = Decimal(20000.00)

# %%
print(f'{c.earnings():.2f}')
# Out:
# 44000.00

# %% [markdown]
# ##  Полиморфная обработка CommissionEmployee и SalariedCommissionEmployee

# %%
e= [c,s]
for i in e:
    print(i)
    print(f'{i.earnings():.2f}\n')
# Out:
# SalariedCommissionEmployee:  Ravil Vasilev
# номер соц страхования: 333-33-3333
# обьем продаж: 20000.00
# комиссионная ставка: 0.60
# base salary: 32000.00
# 44000.00
#
# CommissionEmployee:  Rav Vas
# номер соц страхования: 133-33-3333
# обьем продаж: 10000.00
# комиссионная ставка: 0.06
# 600.00

# %% [markdown]
# ##  Перегрузка операторов

# %%
from complexnumber import Complex
x = Complex(5,9)

# %%
x
# Out:
# (5+9i)

# %%
y = Complex(5,-2)

# %%
y
# Out:
# (5-2i)

# %%
x+y
# Out:
# (10+7i)

# %%
x += y

# %%
x
# Out:
# (10+7i)

# %% [markdown]
# ## Именованные кортежи

# %%
from collections import namedtuple
Card = namedtuple("Card", ['face', 'suit'])

# %%
card = Card(face = 'Ace', suit= 'Spades')

# %%
card.face
# Out:
# 'Ace'

# %%
card.suit
# Out:
# 'Spades'

# %%
card
# Out:
# Card(face='Ace', suit='Spades')

# %%
# метод _make для именнованного кортежа
val = ['Queen','Hearts']
card = Card._make(val)
card
# Out:
# Card(face='Queen', suit='Hearts')

# %%
# метод _asdict
card._asdict()
# Out:
# {'face': 'Queen', 'suit': 'Hearts'}

# %% [markdown]
# ##  Классы данных и автоматическое генерирование кода
